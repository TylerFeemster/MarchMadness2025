# %% [markdown]
# # NCAA competition + AI Lithuania workshop
#
# ![bracket](https://www.ncaa.com/_flysystem/public-s3/images/2025-01/2025-ncaa-tournament-bracket-march-madness-mens.jpg)

# %% [markdown]
# ## <<- Data format explained ->>

# %% [markdown]
# ![box score](https://cdn.geekwire.com/wp-content/uploads/2019/01/boxscore11-e1546622261885.png)

# %% [markdown]
# ## <<- Load the data ->>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import warnings

warnings.filterwarnings("ignore")
pd.set_option("display.max_column", 999)
data_dir = "./data"

# W -> women's basketball, M -> men's basketball
M_regular_results = pd.read_csv(f"{data_dir}/MRegularSeasonDetailedResults.csv")
M_tourney_results = pd.read_csv(f"{data_dir}/MNCAATourneyDetailedResults.csv")
M_seeds = pd.read_csv(f"{data_dir}/MNCAATourneySeeds.csv")

W_regular_results = pd.read_csv(f"{data_dir}/WRegularSeasonDetailedResults.csv")
W_tourney_results = pd.read_csv(f"{data_dir}/WNCAATourneyDetailedResults.csv")
W_seeds = pd.read_csv(f"{data_dir}/WNCAATourneySeeds.csv")

# %%
# join men's and women's data into one file
regular_results = pd.concat([M_regular_results, W_regular_results])
tourney_results = pd.concat([M_tourney_results, W_tourney_results])
seeds = pd.concat([M_seeds, W_seeds])

# %%
season = 2003  # change if you want different cutoff year for your models
regular_results = regular_results.loc[regular_results["Season"] >= season]
tourney_results = tourney_results.loc[tourney_results["Season"] >= season]
seeds = seeds.loc[seeds["Season"] >= season]

# %% [markdown]
# ## <<- Explore the data ->>

# %%
regular_results
# Out:
#        Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0        2003      10     1104      68     1328      62    N      0    27
# 1        2003      10     1272      70     1393      63    N      0    26
# 2        2003      11     1266      73     1437      61    N      0    24
# 3        2003      11     1296      56     1457      50    N      0    18
# 4        2003      11     1400      77     1208      71    N      0    30
# ...       ...     ...      ...     ...      ...     ...  ...    ...   ...
# 81703    2025     131     3471      75     3413      66    A      0    26
# 81704    2025     132     3192      66     3476      49    H      0    23
# 81705    2025     132     3250      74     3119      62    H      0    27
# 81706    2025     132     3293      83     3125      62    N      0    28
# 81707    2025     132     3456      66     3144      63    N      0    27
#
#        WFGA  WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  \
# 0        58      3     14    11    18   14   24    13   23     7     1   22
# 1        62      8     20    10    19   15   28    16   13     4     4   18
# 2        58      8     18    17    29   17   26    15   10     5     2   25
# 3        38      3      9    17    31    6   19    11   12    14     2   18
# 4        61      6     14    11    13   17   22    12   14     4     4   20
# ...     ...    ...    ...   ...   ...  ...  ...   ...  ...   ...   ...  ...
# 81703    62      4     19    19    28    8   31    10   11     6     1   20
# 81704    55      3     21    17    18   10   22    11    9     8     1    8
# 81705    45      5     14    15    17    5   25    15   15     6     0   12
# 81706    54     14     28    13    15    5   33    21   13     2     3   15
# 81707    63      8     23     4     7    5   25     9    9     6     3   13
#
#        LFGM  LFGA  LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  \
# 0        22    53      2     10    16    22   10   22     8   18     9     2
# 1        24    67      6     24     9    20   20   25     7   12     8     6
# 2        22    73      3     26    14    23   31   22     9   12     2     5
# 3        18    49      6     22     8    15   17   20     9   19     4     3
# 4        24    62      6     16    17    27   21   15    12   10     7     1
# ...     ...   ...    ...    ...   ...   ...  ...  ...   ...  ...   ...   ...
# 81703    24    67      9     29     9    14    9   26    14   10     6     5
# 81704    21    57      4     20     3     4   14   22    14   17     4     1
# 81705    25    56      6     17     6    10    8   13    10   10     5     0
# 81706    24    68      2     21    12    14   12   22    11    7     5     0
# 81707    24    55      5     20    10    12    8   33    12   16     4     2
#
#        LPF
# 0       20
# 1       16
# 2       23
# 3       23
# 4       14
# ...    ...
# 81703   22
# 81704   17
# 81705   20
# 81706   16
# 81707   12
#
# [200590 rows x 34 columns]

# %%
tourney_results
# Out:
#      Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0      2003     134     1421      92     1411      84    N      1    32    69
# 1      2003     136     1112      80     1436      51    N      0    31    66
# 2      2003     136     1113      84     1272      71    N      0    31    59
# 3      2003     136     1141      79     1166      73    N      0    29    53
# 4      2003     136     1143      76     1301      74    N      1    27    64
# ..      ...     ...      ...     ...      ...     ...  ...    ...   ...   ...
# 889    2024     147     3163      80     3425      73    A      0    28    58
# 890    2024     147     3234      94     3261      87    H      0    32    69
# 891    2024     151     3234      71     3163      69    N      0    27    59
# 892    2024     151     3376      78     3301      59    N      0    33    66
# 893    2024     153     3376      87     3234      75    N      0    35    73
#
#      WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LFGM  \
# 0       11     29    17    26   14   30    17   12     5     3   22    29
# 1        7     23    11    14   11   36    22   16    10     7    8    20
# 2        6     14    16    22   10   27    18    9     7     4   19    25
# 3        3      7    18    25   11   20    15   18    13     1   19    27
# 4        7     20    15    23   18   20    17   13     8     2   14    25
# ..     ...    ...   ...   ...  ...  ...   ...  ...   ...   ...  ...   ...
# 889      7     15    17    27    5   30    17   12     6     5   21    23
# 890     13     31    17    22    3   29    16   11     6     3   15    34
# 891      7     25    10    14    9   23    12   16     7     1    9    29
# 892      8     19     4     4   10   34    18   15    10     6   16    20
# 893      8     19     9    17   17   32    16   12     8     8   17    25
#
#      LFGA  LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0      67     12     31    14    31   17   28    16   15     5     0   22
# 1      64      4     16     7     7    8   26    12   17    10     3   15
# 2      69      7     28    14    21   20   22    11   12     2     5   18
# 3      60      7     17    12    17   14   17    20   21     6     6   21
# 4      56      9     21    15    20   10   26    16   14     5     8   19
# ..    ...    ...    ...   ...   ...  ...  ...   ...  ...   ...   ...  ...
# 889    70      9     29    18    20   10   25    10    9     6     4   20
# 890    88      8     24    11    17   21   28    15   13     6     6   21
# 891    63      8     25     3     4    6   22    21   14    15     1   18
# 892    62      6     23    13    18   10   18     5   12     9     1    9
# 893    63      9     23    16    20    5   20    13    9     6     4   14
#
# [2276 rows x 34 columns]

# %%
# let's take one random team and see its journey during the 2024 season
season = 2024
teamid = 3163

r = regular_results.loc[
    (regular_results["Season"] == season)
    & ((regular_results["WTeamID"] == teamid) | (regular_results["LTeamID"] == teamid))
]
t = tourney_results.loc[
    (tourney_results["Season"] == season)
    & ((tourney_results["WTeamID"] == teamid) | (tourney_results["LTeamID"] == teamid))
]
r["win"] = np.where(r["WTeamID"] == teamid, "win", "lose")
t["win"] = np.where(t["WTeamID"] == teamid, "win", "lose")
r["type"] = "regular season"
t["type"] = "tournament"

rt = pd.concat([r, t])
rt[["DayNum", "WScore", "LScore", "type", "win"]]
# Out:
#        DayNum  WScore  LScore            type   win
# 70978       2     102      58  regular season   win
# 71162       6      92      81  regular season  lose
# 71309      10      80      48  regular season   win
# 71432      13      62      44  regular season   win
# 71679      18      78      67  regular season  lose
# 71703      19      71      63  regular season   win
# 72099      27      80      68  regular season  lose
# 72161      30      90      63  regular season   win
# 72306      34      76      64  regular season   win
# 72433      40      86      62  regular season   win
# 72530      42      88      62  regular season   win
# 72892      55      95      64  regular season   win
# 72952      58      94      50  regular season   win
# 73208      62      83      55  regular season   win
# 73271      65      85      41  regular season   win
# 73421      68      92      49  regular season   win
# 73595      72      83      59  regular season   win
# 73740      75      88      51  regular season   win
# 73898      78      85      59  regular season   win
# 74108      82      82      67  regular season  lose
# 74241      86      81      60  regular season   win
# 74505      90      78      63  regular season   win
# 74569      93      67      34  regular season   win
# 74840      97      83      65  regular season  lose
# 74878     100      86      40  regular season   win
# 74999     102      85      44  regular season   win
# 75175     105      73      53  regular season   win
# 75467     111     104      67  regular season   win
# 75536     114      67      46  regular season   win
# 75693     117      65      42  regular season   win
# 76036     124      86      53  regular season   win
# 76104     125      58      29  regular season   win
# 76129     126      78      42  regular season   win
# 847       138      86      64      tournament   win
# 871       140      72      64      tournament   win
# 883       145      53      45      tournament   win
# 889       147      80      73      tournament   win
# 891       151      71      69      tournament  lose

# %%
seeds
# Out:
#       Season Seed  TeamID
# 1154    2003  W01    1328
# 1155    2003  W02    1448
# 1156    2003  W03    1393
# 1157    2003  W04    1257
# 1158    2003  W05    1280
# ...      ...  ...     ...
# 1739    2025  Z12    3193
# 1740    2025  Z13    3251
# 1741    2025  Z14    3195
# 1742    2025  Z15    3117
# 1743    2025  Z16    3422
#
# [2896 rows x 3 columns]

# %%
# structure of seeds by division
s = W_seeds.loc[W_seeds["Season"] == 2015]
[s.loc[s["Seed"].str.startswith(d)] for d in ("X", "Y", "Z", "W")]
# Out:
# [      Season Seed  TeamID
#  1104    2015  X01    3268
#  1105    2015  X02    3397
#  1106    2015  X03    3333
#  1107    2015  X04    3181
#  1108    2015  X05    3280
#  1109    2015  X06    3203
#  1110    2015  X07    3151
#  1111    2015  X08    3343
#  1112    2015  X09    3453
#  1113    2015  X10    3338
#  1114    2015  X11    3211
#  1115    2015  X12    3408
#  1116    2015  X13    3107
#  1117    2015  X14    3355
#  1118    2015  X15    3129
#  1119    2015  X16    3308,
#        Season Seed  TeamID
#  1120    2015  Y01    3376
#  1121    2015  Y02    3199
#  1122    2015  Y03    3113
#  1123    2015  Y04    3314
#  1124    2015  Y05    3326
#  1125    2015  Y06    3401
#  1126    2015  Y07    3195
#  1127    2015  Y08    3393
#  1128    2015  Y09    3304
#  1129    2015  Y10    3329
#  1130    2015  Y11    3114
#  1131    2015  Y12    3241
#  1132    2015  Y13    3251
#  1133    2015  Y14    3325
#  1134    2015  Y15    3106
#  1135    2015  Y16    3366,
#        Season Seed  TeamID
#  1136    2015  Z01    3323
#  1137    2015  Z02    3124
#  1138    2015  Z03    3234
#  1139    2015  Z04    3390
#  1140    2015  Z05    3328
#  1141    2015  Z06    3449
#  1142    2015  Z07    3321
#  1143    2015  Z08    3278
#  1144    2015  Z09    3177
#  1145    2015  Z10    3116
#  1146    2015  Z11    3274
#  1147    2015  Z12    3346
#  1148    2015  Z13    3169
#  1149    2015  Z14    3110
#  1150    2015  Z15    3322
#  1151    2015  Z16    3285,
#        Season Seed  TeamID
#  1088    2015  W01    3163
#  1089    2015  W02    3246
#  1090    2015  W03    3257
#  1091    2015  W04    3143
#  1092    2015  W05    3400
#  1093    2015  W06    3378
#  1094    2015  W07    3173
#  1095    2015  W08    3353
#  1096    2015  W09    3371
#  1097    2015  W10    3235
#  1098    2015  W11    3261
#  1099    2015  W12    3443
#  1100    2015  W13    3455
#  1101    2015  W14    3140
#  1102    2015  W15    3398
#  1103    2015  W16    3383]

# %%
# let's see what seed our previous example team had
seeds.loc[(seeds["Season"] == season) & (seeds["TeamID"] == teamid)]
# Out:
#       Season Seed  TeamID
# 1660    2024  Z03    3163

# %% [markdown]
# ## <<- Prepare the data ->>

# %%
# double the dataset with swapped team positions in box scores
def prepare_data(df):
    df = df[["Season", "DayNum", "LTeamID", "LScore", "WTeamID", "WScore", "NumOT",
            "LFGM", "LFGA", "LFGM3", "LFGA3", "LFTM", "LFTA", "LOR", "LDR", "LAst", "LTO", "LStl", "LBlk", "LPF",
            "WFGM", "WFGA", "WFGM3", "WFGA3", "WFTM", "WFTA", "WOR", "WDR", "WAst", "WTO", "WStl", "WBlk", "WPF"]]
    

    # adjustment factor for overtimes, as more stats are accumulated during overtimes
    adjot = (40 + 5 * df["NumOT"]) / 40
    adjcols = ["LScore", "WScore", 
               "LFGM", "LFGA", "LFGM3", "LFGA3", "LFTM", "LFTA", "LOR", "LDR", "LAst", "LTO", "LStl", "LBlk", "LPF",
               "WFGM", "WFGA", "WFGM3", "WFGA3", "WFTM", "WFTA", "WOR", "WDR", "WAst", "WTO", "WStl", "WBlk", "WPF"]
    for col in adjcols:
        df[col] = df[col] / adjot    
    
    dfswap = df.copy()
    df.columns = [x.replace("W", "T1_").replace("L", "T2_") for x in list(df.columns)]
    dfswap.columns = [x.replace("L", "T1_").replace("W", "T2_") for x in list(dfswap.columns)]
    output = pd.concat([df, dfswap]).reset_index(drop=True)
    output["PointDiff"] = output["T1_Score"] - output["T2_Score"]
    output["win"] = (output["PointDiff"] > 0) * 1
    output["men_women"] = (output["T1_TeamID"].apply(lambda t: str(t).startswith("1"))) * 1  # 0: women, 1: men
    return output

regular_data = prepare_data(regular_results)
tourney_data = prepare_data(tourney_results)

# %%
regular_data
# Out:
#         Season  DayNum  T2_TeamID  T2_Score  T1_TeamID  T1_Score  NumOT  \
# 0         2003      10       1328      62.0       1104      68.0      0
# 1         2003      10       1393      63.0       1272      70.0      0
# 2         2003      11       1437      61.0       1266      73.0      0
# 3         2003      11       1457      50.0       1296      56.0      0
# 4         2003      11       1208      71.0       1400      77.0      0
# ...        ...     ...        ...       ...        ...       ...    ...
# 401175    2025     131       3471      75.0       3413      66.0      0
# 401176    2025     132       3192      66.0       3476      49.0      0
# 401177    2025     132       3250      74.0       3119      62.0      0
# 401178    2025     132       3293      83.0       3125      62.0      0
# 401179    2025     132       3456      66.0       3144      63.0      0
#
#         T2_FGM  T2_FGA  T2_FGM3  T2_FGA3  T2_FTM  T2_FTA  T2_OR  T2_DR  \
# 0         22.0    53.0      2.0     10.0    16.0    22.0   10.0   22.0
# 1         24.0    67.0      6.0     24.0     9.0    20.0   20.0   25.0
# 2         22.0    73.0      3.0     26.0    14.0    23.0   31.0   22.0
# 3         18.0    49.0      6.0     22.0     8.0    15.0   17.0   20.0
# 4         24.0    62.0      6.0     16.0    17.0    27.0   21.0   15.0
# ...        ...     ...      ...      ...     ...     ...    ...    ...
# 401175    26.0    62.0      4.0     19.0    19.0    28.0    8.0   31.0
# 401176    23.0    55.0      3.0     21.0    17.0    18.0   10.0   22.0
# 401177    27.0    45.0      5.0     14.0    15.0    17.0    5.0   25.0
# 401178    28.0    54.0     14.0     28.0    13.0    15.0    5.0   33.0
# 401179    27.0    63.0      8.0     23.0     4.0     7.0    5.0   25.0
#
#         T2_Ast  T2_TO  T2_Stl  T2_Blk  T2_PF  T1_FGM  T1_FGA  T1_FGM3  \
# 0          8.0   18.0     9.0     2.0   20.0    27.0    58.0      3.0
# 1          7.0   12.0     8.0     6.0   16.0    26.0    62.0      8.0
# 2          9.0   12.0     2.0     5.0   23.0    24.0    58.0      8.0
# 3          9.0   19.0     4.0     3.0   23.0    18.0    38.0      3.0
# 4         12.0   10.0     7.0     1.0   14.0    30.0    61.0      6.0
# ...        ...    ...     ...     ...    ...     ...     ...      ...
# 401175    10.0   11.0     6.0     1.0   20.0    24.0    67.0      9.0
# 401176    11.0    9.0     8.0     1.0    8.0    21.0    57.0      4.0
# 401177    15.0   15.0     6.0     0.0   12.0    25.0    56.0      6.0
# 401178    21.0   13.0     2.0     3.0   15.0    24.0    68.0      2.0
# 401179     9.0    9.0     6.0     3.0   13.0    24.0    55.0      5.0
#
#         T1_FGA3  T1_FTM  T1_FTA  T1_OR  T1_DR  T1_Ast  T1_TO  T1_Stl  T1_Blk  \
# 0          14.0    11.0    18.0   14.0   24.0    13.0   23.0     7.0     1.0
# 1          20.0    10.0    19.0   15.0   28.0    16.0   13.0     4.0     4.0
# 2          18.0    17.0    29.0   17.0   26.0    15.0   10.0     5.0     2.0
# 3           9.0    17.0    31.0    6.0   19.0    11.0   12.0    14.0     2.0
# 4          14.0    11.0    13.0   17.0   22.0    12.0   14.0     4.0     4.0
# ...         ...     ...     ...    ...    ...     ...    ...     ...     ...
# 401175     29.0     9.0    14.0    9.0   26.0    14.0   10.0     6.0     5.0
# 401176     20.0     3.0     4.0   14.0   22.0    14.0   17.0     4.0     1.0
# 401177     17.0     6.0    10.0    8.0   13.0    10.0   10.0     5.0     0.0
# 401178     21.0    12.0    14.0   12.0   22.0    11.0    7.0     5.0     0.0
# 401179     20.0    10.0    12.0    8.0   33.0    12.0   16.0     4.0     2.0
#
#         T1_PF  PointDiff  win  men_women
# 0        22.0        6.0    1          1
# 1        18.0        7.0    1          1
# 2        25.0       12.0    1          1
# 3        18.0        6.0    1          1
# 4        20.0        6.0    1          1
# ...       ...        ...  ...        ...
# 401175   22.0       -9.0    0          0
# 401176   17.0      -17.0    0          0
# 401177   20.0      -12.0    0          0
# 401178   16.0      -21.0    0          0
# 401179   12.0       -3.0    0          0
#
# [401180 rows x 36 columns]

# %%
tourney_data
# Out:
#       Season  DayNum  T2_TeamID   T2_Score  T1_TeamID   T1_Score  NumOT  \
# 0       2003     134       1411  74.666667       1421  81.777778      1
# 1       2003     136       1436  51.000000       1112  80.000000      0
# 2       2003     136       1272  71.000000       1113  84.000000      0
# 3       2003     136       1166  73.000000       1141  79.000000      0
# 4       2003     136       1301  65.777778       1143  67.555556      1
# ...      ...     ...        ...        ...        ...        ...    ...
# 4547    2024     147       3163  80.000000       3425  73.000000      0
# 4548    2024     147       3234  94.000000       3261  87.000000      0
# 4549    2024     151       3234  71.000000       3163  69.000000      0
# 4550    2024     151       3376  78.000000       3301  59.000000      0
# 4551    2024     153       3376  87.000000       3234  75.000000      0
#
#          T2_FGM     T2_FGA    T2_FGM3    T2_FGA3     T2_FTM     T2_FTA  \
# 0     25.777778  59.555556  10.666667  27.555556  12.444444  27.555556
# 1     20.000000  64.000000   4.000000  16.000000   7.000000   7.000000
# 2     25.000000  69.000000   7.000000  28.000000  14.000000  21.000000
# 3     27.000000  60.000000   7.000000  17.000000  12.000000  17.000000
# 4     22.222222  49.777778   8.000000  18.666667  13.333333  17.777778
# ...         ...        ...        ...        ...        ...        ...
# 4547  28.000000  58.000000   7.000000  15.000000  17.000000  27.000000
# 4548  32.000000  69.000000  13.000000  31.000000  17.000000  22.000000
# 4549  27.000000  59.000000   7.000000  25.000000  10.000000  14.000000
# 4550  33.000000  66.000000   8.000000  19.000000   4.000000   4.000000
# 4551  35.000000  73.000000   8.000000  19.000000   9.000000  17.000000
#
#           T2_OR      T2_DR     T2_Ast      T2_TO     T2_Stl    T2_Blk  \
# 0     15.111111  24.888889  14.222222  13.333333   4.444444  0.000000
# 1      8.000000  26.000000  12.000000  17.000000  10.000000  3.000000
# 2     20.000000  22.000000  11.000000  12.000000   2.000000  5.000000
# 3     14.000000  17.000000  20.000000  21.000000   6.000000  6.000000
# 4      8.888889  23.111111  14.222222  12.444444   4.444444  7.111111
# ...         ...        ...        ...        ...        ...       ...
# 4547   5.000000  30.000000  17.000000  12.000000   6.000000  5.000000
# 4548   3.000000  29.000000  16.000000  11.000000   6.000000  3.000000
# 4549   9.000000  23.000000  12.000000  16.000000   7.000000  1.000000
# 4550  10.000000  34.000000  18.000000  15.000000  10.000000  6.000000
# 4551  17.000000  32.000000  16.000000  12.000000   8.000000  8.000000
#
#           T2_PF     T1_FGM     T1_FGA   T1_FGM3    T1_FGA3     T1_FTM  \
# 0     19.555556  28.444444  61.333333  9.777778  25.777778  15.111111
# 1     15.000000  31.000000  66.000000  7.000000  23.000000  11.000000
# 2     18.000000  31.000000  59.000000  6.000000  14.000000  16.000000
# 3     21.000000  29.000000  53.000000  3.000000   7.000000  18.000000
# 4     16.888889  24.000000  56.888889  6.222222  17.777778  13.333333
# ...         ...        ...        ...       ...        ...        ...
# 4547  21.000000  23.000000  70.000000  9.000000  29.000000  18.000000
# 4548  15.000000  34.000000  88.000000  8.000000  24.000000  11.000000
# 4549   9.000000  29.000000  63.000000  8.000000  25.000000   3.000000
# 4550  16.000000  20.000000  62.000000  6.000000  23.000000  13.000000
# 4551  17.000000  25.000000  63.000000  9.000000  23.000000  16.000000
#
#          T1_FTA      T1_OR      T1_DR     T1_Ast      T1_TO     T1_Stl  \
# 0     23.111111  12.444444  26.666667  15.111111  10.666667   4.444444
# 1     14.000000  11.000000  36.000000  22.000000  16.000000  10.000000
# 2     22.000000  10.000000  27.000000  18.000000   9.000000   7.000000
# 3     25.000000  11.000000  20.000000  15.000000  18.000000  13.000000
# 4     20.444444  16.000000  17.777778  15.111111  11.555556   7.111111
# ...         ...        ...        ...        ...        ...        ...
# 4547  20.000000  10.000000  25.000000  10.000000   9.000000   6.000000
# 4548  17.000000  21.000000  28.000000  15.000000  13.000000   6.000000
# 4549   4.000000   6.000000  22.000000  21.000000  14.000000  15.000000
# 4550  18.000000  10.000000  18.000000   5.000000  12.000000   9.000000
# 4551  20.000000   5.000000  20.000000  13.000000   9.000000   6.000000
#
#         T1_Blk      T1_PF  PointDiff  win  men_women
# 0     2.666667  19.555556   7.111111    1          1
# 1     7.000000   8.000000  29.000000    1          1
# 2     4.000000  19.000000  13.000000    1          1
# 3     1.000000  19.000000   6.000000    1          1
# 4     1.777778  12.444444   1.777778    1          1
# ...        ...        ...        ...  ...        ...
# 4547  4.000000  20.000000  -7.000000    0          0
# 4548  6.000000  21.000000  -7.000000    0          0
# 4549  1.000000  18.000000  -2.000000    0          0
# 4550  1.000000   9.000000 -19.000000    0          0
# 4551  4.000000  14.000000 -12.000000    0          0
#
# [4552 rows x 36 columns]

# %%
# let's take an example match to double check if the same match is entered correctly in our dataset
season = regular_data["Season"] == 2025
t1, t2 = 1182, 1433
match1 = (regular_data["T1_TeamID"] == t1) & (regular_data["T2_TeamID"] == t2)
match2 = (regular_data["T1_TeamID"] == t2) & (regular_data["T2_TeamID"] == t1)
regular_data.loc[season & (match1 | match2)]
# Out:
#         Season  DayNum  T2_TeamID  T2_Score  T1_TeamID  T1_Score  NumOT  \
# 118444    2025     120       1182      62.0       1433      71.0      0
# 319034    2025     120       1433      71.0       1182      62.0      0
#
#         T2_FGM  T2_FGA  T2_FGM3  T2_FGA3  T2_FTM  T2_FTA  T2_OR  T2_DR  \
# 118444    21.0    51.0      4.0     16.0    16.0    24.0   11.0   19.0
# 319034    23.0    55.0      8.0     22.0    17.0    21.0   12.0   22.0
#
#         T2_Ast  T2_TO  T2_Stl  T2_Blk  T2_PF  T1_FGM  T1_FGA  T1_FGM3  \
# 118444     9.0   15.0     8.0     5.0   16.0    23.0    55.0      8.0
# 319034    10.0   14.0     9.0     4.0   23.0    21.0    51.0      4.0
#
#         T1_FGA3  T1_FTM  T1_FTA  T1_OR  T1_DR  T1_Ast  T1_TO  T1_Stl  T1_Blk  \
# 118444     22.0    17.0    21.0   12.0   22.0    10.0   14.0     9.0     4.0
# 319034     16.0    16.0    24.0   11.0   19.0     9.0   15.0     8.0     5.0
#
#         T1_PF  PointDiff  win  men_women
# 118444   23.0        9.0    1          1
# 319034   16.0       -9.0    0          1

# %% [markdown]
# ## <<- Easy difficulty features ->>

# %%
# extract seed number from `Seed` field
seeds["seed"] = seeds["Seed"].apply(lambda x: int(x[1:3]))
seeds
# Out:
#       Season Seed  TeamID  seed
# 1154    2003  W01    1328     1
# 1155    2003  W02    1448     2
# 1156    2003  W03    1393     3
# 1157    2003  W04    1257     4
# 1158    2003  W05    1280     5
# ...      ...  ...     ...   ...
# 1739    2025  Z12    3193    12
# 1740    2025  Z13    3251    13
# 1741    2025  Z14    3195    14
# 1742    2025  Z15    3117    15
# 1743    2025  Z16    3422    16
#
# [2896 rows x 4 columns]

# %%
seeds_T1 = seeds[["Season", "TeamID", "seed"]].copy()
seeds_T2 = seeds[["Season", "TeamID", "seed"]].copy()
seeds_T1.columns = ["Season", "T1_TeamID", "T1_seed"]
seeds_T2.columns = ["Season", "T2_TeamID", "T2_seed"]

tourney_data = tourney_data[["Season", "T1_TeamID", "T2_TeamID", "PointDiff", "win", "men_women"]]
tourney_data = pd.merge(tourney_data, seeds_T1, on=["Season", "T1_TeamID"], how="left")
tourney_data = pd.merge(tourney_data, seeds_T2, on=["Season", "T2_TeamID"], how="left")
tourney_data["Seed_diff"] = tourney_data["T2_seed"] - tourney_data["T1_seed"]

tourney_data
# Out:
#       Season  T1_TeamID  T2_TeamID  PointDiff  win  men_women  T1_seed  \
# 0       2003       1421       1411   7.111111    1          1       16
# 1       2003       1112       1436  29.000000    1          1        1
# 2       2003       1113       1272  13.000000    1          1       10
# 3       2003       1141       1166   6.000000    1          1       11
# 4       2003       1143       1301   1.777778    1          1        8
# ...      ...        ...        ...        ...  ...        ...      ...
# 4547    2024       3425       3163  -7.000000    0          0        1
# 4548    2024       3261       3234  -7.000000    0          0        3
# 4549    2024       3163       3234  -2.000000    0          0        3
# 4550    2024       3301       3376 -19.000000    0          0        3
# 4551    2024       3234       3376 -12.000000    0          0        1
#
#       T2_seed  Seed_diff
# 0          16          0
# 1          16         15
# 2           7         -3
# 3           6         -5
# 4           9          1
# ...       ...        ...
# 4547        3          2
# 4548        1         -2
# 4549        1         -2
# 4550        1         -2
# 4551        1          0
#
# [4552 rows x 9 columns]

# %%
# let's see if __seed__ is predictive for predicting the point difference
tmpmean = tourney_data.pivot_table(columns="men_women", index="T1_seed", values="PointDiff", aggfunc="mean").ffill()
tmpstd = tourney_data.pivot_table(columns="men_women", index="T1_seed", values="PointDiff", aggfunc="std").ffill()
fig, axis = plt.subplots(ncols=2, figsize=(12, 4))
(line_1,) = axis[0].plot(tmpmean.index, tmpmean[0], "b-")
fill_1 = axis[0].fill_between(tmpmean.index, tmpmean[0] - tmpstd[0], tmpmean[0] + tmpstd[0], color="b", alpha=0.1)
(line_2,) = axis[1].plot(tmpmean.index, tmpmean[1], "r--")
fill_2 = axis[1].fill_between(tmpmean.index, tmpmean[1] - tmpstd[1], tmpmean[1] + tmpstd[1], color="r", alpha=0.1)
plt.margins(x=0)
plt.legend([(line_1, fill_1), (line_2, fill_2)], ["Women", "Men"])

# %%
# let's see __seed difference__ is predictive for predicting the point difference
tmpmean = tourney_data.pivot_table(columns="men_women", index="Seed_diff", values="PointDiff", aggfunc="mean").ffill()
tmpstd = tourney_data.pivot_table(columns="men_women", index="Seed_diff", values="PointDiff", aggfunc="std").ffill()
fig, axis = plt.subplots(ncols=2, figsize=(12, 4))
(line_1,) = axis[0].plot(tmpmean.index, tmpmean[0], "b-")
fill_1 = axis[0].fill_between(tmpmean.index, tmpmean[0] - tmpstd[0], tmpmean[0] + tmpstd[0], color="b", alpha=0.1)
(line_2,) = axis[1].plot(tmpmean.index, tmpmean[1], "r--")
fill_2 = axis[1].fill_between(tmpmean.index, tmpmean[1] - tmpstd[1], tmpmean[1] + tmpstd[1], color="r", alpha=0.1)
plt.margins(x=0)
plt.legend([(line_1, fill_1), (line_2, fill_2)], ["Women", "Men"])

# %% [markdown]
# ## <<- Medium difficulty features ->>

# %%
# box score columns, for which we want features to our model
boxcols = [
    "T1_Score", "T1_FGM", "T1_FGA", "T1_FGM3", "T1_FGA3", "T1_FTM", "T1_FTA",
    "T1_OR", "T1_DR", "T1_Ast", "T1_TO", "T1_Stl", "T1_Blk", "T1_PF",
    "T2_Score", "T2_FGM", "T2_FGA", "T2_FGM3", "T2_FGA3", "T2_FTM", "T2_FTA",
    "T2_OR", "T2_DR", "T2_Ast", "T2_TO", "T2_Stl", "T2_Blk", "T2_PF",
    "PointDiff",
]

# %% [markdown]
# #### 1. Let's define a single match {**`T`**, **`OPP`**}. This means that **`T=TEAM(x)`** plays against an opponent team **`OPP=TEAM(y1)`**
# #### 2. During regular season, team **`T`** plays multiple games {**`T`**, **`OPP1`**}, {**`T`**, **`OPP2`**}, ...; against different opponents **`OPP1=TEAM(y1)`**, **`OPP2=TEAM(y2)`**, ...
# #### 3. We can calculate regular season average performance for the team **`T`** : **`average[T]`**
# #### 4. We can also calculate how opponents perform on average when they play a game against team **`T`** : **`average[T_OPP1,T_OPP2,...]`**
# #### 5. Let's play a new match: {**`T1`**, **`T2`**}
# #### 6. We can collect performance data for the **`T1`**: **`average[T1]`** and **`average[T1_OPP1,T1_OPP2,...]`**
# #### 7. We can collect performance data for the **`T2`**: **`average[T2]`** and **`average[T2_OPP1,T2_OPP2,...]`**
# #### 8. Then we can combine all data: **`average[T1]`**,**`average[T1_OPP1,T1_OPP2,...]`**, **`average[T2]`**, **`average[T2_OPP1,T2_OPP2,...]`**
# #### 9. Use this data to predict the output of a match between **`T1`** and **`T2`**

# %%
# calculate season averages
ss = regular_data.groupby(["Season", "T1_TeamID"])[boxcols].agg("mean").reset_index()

ss_T1 = ss.copy()
ss_T1.columns = ["T1_avg_" + x.replace("T1_", "").replace("T2_", "opponent_") for x in list(ss_T1.columns)]
ss_T1 = ss_T1.rename({"T1_avg_Season": "Season", "T1_avg_TeamID": "T1_TeamID"}, axis=1)
ss_T2 = ss.copy()
ss_T2.columns = ["T2_avg_" + x.replace("T1_", "").replace("T2_", "opponent_") for x in list(ss_T2.columns)]
ss_T2 = ss_T2.rename({"T2_avg_Season": "Season", "T2_avg_TeamID": "T2_TeamID"}, axis=1)

tourney_data = pd.merge(tourney_data, ss_T1, on=["Season", "T1_TeamID"], how="left")
tourney_data = pd.merge(tourney_data, ss_T2, on=["Season", "T2_TeamID"], how="left")
tourney_data
# Out:
#       Season  T1_TeamID  T2_TeamID  PointDiff  win  men_women  T1_seed  \
# 0       2003       1421       1411   7.111111    1          1       16
# 1       2003       1112       1436  29.000000    1          1        1
# 2       2003       1113       1272  13.000000    1          1       10
# 3       2003       1141       1166   6.000000    1          1       11
# 4       2003       1143       1301   1.777778    1          1        8
# ...      ...        ...        ...        ...  ...        ...      ...
# 4547    2024       3425       3163  -7.000000    0          0        1
# 4548    2024       3261       3234  -7.000000    0          0        3
# 4549    2024       3163       3234  -2.000000    0          0        3
# 4550    2024       3301       3376 -19.000000    0          0        3
# 4551    2024       3234       3376 -12.000000    0          0        1
#
#       T2_seed  Seed_diff  T1_avg_Score  T1_avg_FGM  T1_avg_FGA  T1_avg_FGM3  \
# 0          16          0     69.615326   23.847510   55.639847     6.348659
# 1          16         15     84.511905   30.067460   65.087302     6.984127
# 2           7         -3     75.344828   27.003831   56.436782     3.977011
# 3           6         -5     79.344828   26.620690   52.689655     6.827586
# 4           9          1     73.636015   27.015326   57.946360     6.314176
# ...       ...        ...           ...         ...         ...          ...
# 4547        3          2     74.064516   26.303226   61.793548     7.503226
# 4548        1         -2     86.696970   31.212121   66.818182     4.242424
# 4549        1         -2     79.878788   30.545455   61.636364     7.090909
# 4550        1         -2     72.979798   26.680135   62.191919     5.996633
# 4551        1          0     92.222222   32.909091   65.350168    11.225589
#
#       T1_avg_FGA3  T1_avg_FTM  T1_avg_FTA  T1_avg_OR  T1_avg_DR  T1_avg_Ast  \
# 0       17.658238   15.571648   20.428352  12.011494  22.652874   12.740230
# 1       19.857143   17.392857   24.813492  15.051587  27.440476   17.488095
# 2       12.475096   17.360153   25.877395  13.501916  23.111111   15.448276
# 3       17.931034   19.275862   25.172414  10.586207  23.275862   15.620690
# 4       16.789272   13.291188   19.371648  11.114943  24.095785   15.816092
# ...           ...         ...         ...        ...        ...         ...
# 4547    21.090323   13.954839   18.651613  10.354839  23.722581   14.709677
# 4548    13.212121   20.030303   26.727273  14.969697  27.666667   16.545455
# 4549    19.787879   11.696970   15.484848   8.121212  25.272727   19.303030
# 4550    18.457912   13.622896   18.474747   9.262626  29.158249   13.454545
# 4551    29.400673   15.178451   19.420875   9.057239  28.077441   21.720539
#
#       T1_avg_TO  T1_avg_Stl  T1_avg_Blk  T1_avg_PF  T1_avg_opponent_Score  \
# 0     15.931034    6.927969    2.937165  18.769349              76.947893
# 1     14.666667    8.396825    4.186508  17.587302              69.531746
# 2     13.881226    5.164751    4.191571  19.260536              68.574713
# 3     18.241379    7.103448    4.000000  20.965517              73.241379
# 4     14.019157    6.455939    2.758621  16.888889              68.923372
# ...         ...         ...         ...        ...                    ...
# 4547  11.716129    7.883871    5.619355  15.993548              61.561290
# 4548  15.212121   10.787879    5.484848  16.090909              62.545455
# 4549  12.363636    9.818182    3.787879  14.363636              56.969697
# 4550  12.222222    6.424242    4.363636  12.451178              59.205387
# 4551  13.323232    7.508418    3.299663  14.565657              71.272727
#
#       T1_avg_opponent_FGM  T1_avg_opponent_FGA  T1_avg_opponent_FGM3  \
# 0               27.242146            59.712644              7.459004
# 1               26.115079            64.107143              6.253968
# 2               24.574713            55.176245              5.398467
# 3               26.344828            57.931034              4.965517
# 4               25.072797            58.114943              7.034483
# ...                   ...                  ...                   ...
# 4547            22.348387            57.690323              5.406452
# 4548            22.818182            62.121212              6.272727
# 4549            21.090909            58.212121              6.121212
# 4550            22.666667            64.050505              6.367003
# 4551            26.228956            65.468013              7.764310
#
#       T1_avg_opponent_FGA3  T1_avg_opponent_FTM  T1_avg_opponent_FTA  \
# 0                20.307280            15.004598            22.157854
# 1                19.797619            11.047619            17.503968
# 2                15.766284            14.026820            20.375479
# 3                13.896552            15.586207            21.965517
# 4                21.237548            11.743295            17.214559
# ...                    ...                  ...                  ...
# 4547             17.696774            11.458065            15.225806
# 4548             21.181818            10.636364            15.969697
# 4549             21.575758             8.666667            12.242424
# 4550             21.835017             7.505051             9.936027
# 4551             25.084175            11.050505            14.841751
#
#       T1_avg_opponent_OR  T1_avg_opponent_DR  T1_avg_opponent_Ast  \
# 0              13.463602           22.401533            15.563218
# 1              12.980159           23.067460            15.341270
# 2              10.931034           20.367816            13.946360
# 3              12.241379           18.896552            11.793103
# 4              11.049808           22.659004            15.881226
# ...                  ...                 ...                  ...
# 4547            7.567742           22.251613            13.219355
# 4548            8.787879           18.878788            10.818182
# 4549            7.484848           19.636364            11.757576
# 4550            8.565657           23.885522            10.747475
# 4551            8.740741           21.531987            14.087542
#
#       T1_avg_opponent_TO  T1_avg_opponent_Stl  T1_avg_opponent_Blk  \
# 0              12.568582             8.679693             4.141762
# 1              16.738095             5.904762             2.369048
# 2              15.402299             5.950192             3.908046
# 3              16.068966             8.448276             2.482759
# 4              14.708812             5.865900             2.482759
# ...                  ...                  ...                  ...
# 4547           14.464516             6.264516             2.651613
# 4548           18.939394             8.000000             3.818182
# 4549           15.969697             5.212121             2.181818
# 4550           12.558923             6.373737             3.535354
# 4551           14.333333             7.010101             2.811448
#
#       T1_avg_opponent_PF  T1_avg_PointDiff  T2_avg_Score  T2_avg_FGM  \
# 0              18.265134         -7.332567     72.533333   24.644444
# 1              21.888889         14.980159     67.255172   24.634483
# 2              22.624521          6.770115     74.210728   26.183908
# 3              21.689655          6.103448     79.006734   28.619529
# 4              18.919540          4.712644     72.122222   24.248148
# ...                  ...               ...           ...         ...
# 4547           18.329032         12.503226     79.878788   30.545455
# 4548           22.151515         24.151515     92.222222   32.909091
# 4549           16.303030         22.909091     92.222222   32.909091
# 4550           17.683502         13.774411     86.062500   33.218750
# 4551           19.114478         20.949495     86.062500   33.218750
#
#       T2_avg_FGA  T2_avg_FGM3  T2_avg_FGA3  T2_avg_FTM  T2_avg_FTA  T2_avg_OR  \
# 0      55.051852     5.911111    18.437037   17.333333   27.929630  13.103704
# 1      55.427586     5.241379    15.310345   12.744828   19.379310  12.903448
# 2      59.762452     6.969349    19.996169   14.873563   22.766284  14.019157
# 3      57.289562     7.942761    20.424242   13.824916   19.952862  10.848485
# 4      53.129630     7.940741    22.429630   15.685185   20.385185   9.700000
# ...          ...          ...          ...         ...         ...        ...
# 4547   61.636364     7.090909    19.787879   11.696970   15.484848   8.121212
# 4548   65.350168    11.225589    29.400673   15.178451   19.420875   9.057239
# 4549   65.350168    11.225589    29.400673   15.178451   19.420875   9.057239
# 4550   66.812500     6.468750    16.312500   13.156250   19.187500  12.406250
# 4551   66.812500     6.468750    16.312500   13.156250   19.187500  12.406250
#
#       T2_avg_DR  T2_avg_Ast  T2_avg_TO  T2_avg_Stl  T2_avg_Blk  T2_avg_PF  \
# 0     24.677778   14.140741  15.166667    6.407407    2.222222  18.211111
# 1     25.565517   14.096552  13.993103    6.841379    2.958621  15.703448
# 2     25.846743   16.555556  13.739464    7.363985    5.042146  18.693487
# 3     23.097643   16.784512  13.309764    8.370370    4.427609  17.205387
# 4     21.907407   14.614815  14.129630    7.737037    3.048148  18.603704
# ...         ...         ...        ...         ...         ...        ...
# 4547  25.272727   19.303030  12.363636    9.818182    3.787879  14.363636
# 4548  28.077441   21.720539  13.323232    7.508418    3.299663  14.565657
# 4549  28.077441   21.720539  13.323232    7.508418    3.299663  14.565657
# 4550  29.718750   18.875000  13.156250    8.750000    8.000000  14.312500
# 4551  29.718750   18.875000  13.156250    8.750000    8.000000  14.312500
#
#       T2_avg_opponent_Score  T2_avg_opponent_FGM  T2_avg_opponent_FGA  \
# 0                 70.585185            25.581481            60.140741
# 1                 62.565517            22.600000            54.696552
# 2                 65.517241            23.164751            57.593870
# 3                 64.107744            23.797980            55.148148
# 4                 67.751852            23.337037            52.925926
# ...                     ...                  ...                  ...
# 4547              56.969697            21.090909            58.212121
# 4548              71.272727            26.228956            65.468013
# 4549              71.272727            26.228956            65.468013
# 4550              56.312500            20.687500            64.656250
# 4551              56.312500            20.687500            64.656250
#
#       T2_avg_opponent_FGM3  T2_avg_opponent_FGA3  T2_avg_opponent_FTM  \
# 0                 7.507407             23.051852            11.914815
# 1                 7.034483             21.344828            10.331034
# 2                 5.854406             18.218391            13.333333
# 3                 4.868687             14.282828            11.643098
# 4                 5.703704             16.903704            15.374074
# ...                    ...                   ...                  ...
# 4547              6.121212             21.575758             8.666667
# 4548              7.764310             25.084175            11.050505
# 4549              7.764310             25.084175            11.050505
# 4550              5.343750             20.031250             9.593750
# 4551              5.343750             20.031250             9.593750
#
#       T2_avg_opponent_FTA  T2_avg_opponent_OR  T2_avg_opponent_DR  \
# 0               18.655556           11.881481           22.781481
# 1               15.482759            9.517241           21.641379
# 2               20.659004           12.295019           23.482759
# 3               16.619529           11.020202           21.289562
# 4               21.129630           10.514815           21.348148
# ...                   ...                 ...                 ...
# 4547            12.242424            7.484848           19.636364
# 4548            14.841751            8.740741           21.531987
# 4549            14.841751            8.740741           21.531987
# 4550            14.031250            9.250000           19.281250
# 4551            14.031250            9.250000           19.281250
#
#       T2_avg_opponent_Ast  T2_avg_opponent_TO  T2_avg_opponent_Stl  \
# 0               13.718519           14.259259             7.977778
# 1               13.158621           12.910345             7.082759
# 2               13.237548           15.019157             7.252874
# 3               12.329966           17.006734             6.306397
# 4               12.511111           14.581481             7.418519
# ...                   ...                 ...                  ...
# 4547            11.757576           15.969697             5.212121
# 4548            14.087542           14.333333             7.010101
# 4549            14.087542           14.333333             7.010101
# 4550            10.062500           14.812500             6.625000
# 4551            10.062500           14.812500             6.625000
#
#       T2_avg_opponent_Blk  T2_avg_opponent_PF  T2_avg_PointDiff
# 0                2.596296           21.533333          1.948148
# 1                3.655172           17.772414          4.689655
# 2                3.153257           19.827586          8.693487
# 3                2.569024           19.323232         14.898990
# 4                2.811111           19.262963          4.370370
# ...                   ...                 ...               ...
# 4547             2.181818           16.303030         22.909091
# 4548             2.811448           19.114478         20.949495
# 4549             2.811448           19.114478         20.949495
# 4550             3.125000           16.812500         29.750000
# 4551             3.125000           16.812500         29.750000
#
# [4552 rows x 67 columns]

# %% [markdown]
# ## <<- Hard difficulty features ->>

# %% [markdown]
# ![chess](https://preview.redd.it/rapid-elo-distribution-september-2023-v0-ebk9mbac3cpb1.png?width=1080&crop=smart&auto=webp&s=a1dfc1d91c06cc3f96229a7a0f9c89ffc3bba2ef)

# %%
def update_elo(winner_elo, loser_elo):
    expected_win = expected_result(winner_elo, loser_elo)
    change_in_elo = k_factor * (1 - expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo


def expected_result(elo_a, elo_b):
    return 1.0 / (1 + 10 ** ((elo_b - elo_a) / elo_width))

base_elo = 1000
elo_width = 400
k_factor = 100

elos = []
for season in sorted(set(seeds["Season"])):
    ss = regular_data.loc[regular_data["Season"] == season]
    ss = ss.loc[ss["win"] == 1].reset_index(drop=True)
    teams = set(ss["T1_TeamID"]) | set(ss["T2_TeamID"])
    elo = dict(zip(teams, [base_elo] * len(teams)))
    for i in range(ss.shape[0]):
        w_team, l_team = ss.loc[i, "T1_TeamID"], ss.loc[i, "T2_TeamID"]
        w_elo, l_elo = elo[w_team], elo[l_team]
        w_elo_new, l_elo_new = update_elo(w_elo, l_elo)
        elo[w_team] = w_elo_new
        elo[l_team] = l_elo_new
    elo = pd.DataFrame.from_dict(elo, orient="index").reset_index()
    elo = elo.rename({"index": "TeamID", 0: "elo"}, axis=1)
    elo["Season"] = season
    elos.append(elo)
elos = pd.concat(elos)

elos_T1 = elos.copy().rename({"TeamID": "T1_TeamID", "elo": "T1_elo"}, axis=1)
elos_T2 = elos.copy().rename({"TeamID": "T2_TeamID", "elo": "T2_elo"}, axis=1)
tourney_data = pd.merge(tourney_data, elos_T1, on=["Season", "T1_TeamID"], how="left")
tourney_data = pd.merge(tourney_data, elos_T2, on=["Season", "T2_TeamID"], how="left")
tourney_data["elo_diff"] = tourney_data["T1_elo"] - tourney_data["T2_elo"]

# %%
tmp = pd.merge(elos, tourney_data[['Season', 'T1_TeamID']].drop_duplicates(), 
               left_on = ['Season', 'TeamID'], 
               right_on = ['Season', 'T1_TeamID'],
               how = 'left')

plt.figure(figsize=(6,4))
seaborn.distplot(tmp.loc[pd.isnull(tmp['T1_TeamID']),'elo'], kde=False)
seaborn.distplot(tmp.loc[~pd.isnull(tmp['T1_TeamID']),'elo'], kde=False)
# Out:
# <Axes: xlabel='elo'>

# %%
plt.figure(figsize=(6,4))
seaborn.stripplot(data = tourney_data, y = 'T1_elo', x = 'T1_seed', size=3)
# Out:
# <Axes: xlabel='T1_seed', ylabel='T1_elo'>

# %%
plt.figure(figsize=(12,4))
seaborn.stripplot(data = tourney_data, y = 'elo_diff', x = 'Seed_diff', hue='win', dodge=True, size=3)
seaborn.lineplot([0]*29,color='gray',lw = 1)
# Out:
# <Axes: xlabel='Seed_diff', ylabel='elo_diff'>

# %% [markdown]
# ## <<- Hardest difficulty features ->>

# %% [markdown]
# ![exponent](https://media1.shmoop.com/images/algebra/alg_fn_nonlin_narr_graphik_30.png)

# %%
import statsmodels.api as sm
import tqdm

regular_data["ST1"] = regular_data.apply(lambda t: str(int(t["Season"])) + "/" + str(int(t["T1_TeamID"])), axis=1)
regular_data["ST2"] = regular_data.apply(lambda t: str(int(t["Season"])) + "/" + str(int(t["T2_TeamID"])), axis=1)
seeds_T1["ST1"] = seeds_T1.apply(lambda t: str(int(t["Season"])) + "/" + str(int(t["T1_TeamID"])), axis=1)
seeds_T2["ST2"] = seeds_T2.apply(lambda t: str(int(t["Season"])) + "/" + str(int(t["T2_TeamID"])), axis=1)

# collect tourney teams
st = set(seeds_T1["ST1"]) | set(seeds_T2["ST2"])
# append non-tourney teams which were able to beat tourney team at least once
st = st | set(regular_data.loc[(regular_data["T1_Score"] > regular_data["T2_Score"]) & 
                               (regular_data["ST2"].isin(st)), "ST1"])

def team_quality(season, men_women):
    # mixed effects: fixed intercept=0, random slope
    formula = "PointDiff~-1+T1_TeamID+T2_TeamID"
    glm = sm.GLM.from_formula(
        formula=formula,
        data=dt.loc[(dt["Season"] == season) & (dt["men_women"] == men_women), :],
        family=sm.families.Gaussian(),
    ).fit()
    
    quality = pd.DataFrame(glm.params).reset_index()
    quality.columns = ["TeamID", "quality"]
    quality["quality"] = quality["quality"]
    quality["Season"] = season
    quality = quality.loc[quality.TeamID.str.contains("T1_")].reset_index(drop=True)
    quality["TeamID"] = quality["TeamID"].apply(lambda x: x[10:14]).astype(int)
    return quality


glm_quality = []

dt = regular_data.loc[regular_data["ST1"].isin(st) | regular_data["ST2"].isin(st)]
dt["T1_TeamID"] = dt["T1_TeamID"].astype(str)
dt["T2_TeamID"] = dt["T2_TeamID"].astype(str)
dt.loc[~dt["ST1"].isin(st), "T1_TeamID"] = "0000"
dt.loc[~dt["ST2"].isin(st), "T2_TeamID"] = "0000"
seasons = sorted(set(seeds["Season"]))
for s in tqdm.tqdm(seasons, unit="season"):
    if s >= 2010:  # min season for women
        glm_quality.append(team_quality(s, 0))
    if s >= 2003:  # min season for men
        glm_quality.append(team_quality(s, 1))

glm_quality = pd.concat(glm_quality).reset_index(drop=True)

glm_quality_T1 = glm_quality.copy()
glm_quality_T2 = glm_quality.copy()
glm_quality_T1.columns = ["T1_TeamID", "T1_quality", "Season"]
glm_quality_T2.columns = ["T2_TeamID", "T2_quality", "Season"]
tourney_data = pd.merge(tourney_data, glm_quality_T1, on=["Season", "T1_TeamID"], how="left")
tourney_data = pd.merge(tourney_data, glm_quality_T2, on=["Season", "T2_TeamID"], how="left")
tourney_data["diff_quality"] = tourney_data["T1_quality"] - tourney_data["T2_quality"]
# Out:
# 100%|██████████| 22/22 [01:47<00:00,  4.91s/season]

# %%
tmp = (
    tourney_data[["Season", "men_women", "T1_seed", "T1_quality"]]
    .drop_duplicates()
    .sort_values("T1_quality")
    .reset_index(drop=True)
)

fig, axs = plt.subplots(ncols=2, figsize=(12, 4))

seaborn.lineplot(tmp.loc[tmp["men_women"] == 0, "T1_quality"], color="lightgray", ax=axs[0])
seaborn.scatterplot(tmp.loc[(tmp["men_women"] == 0) & (tmp.T1_seed == 1), "T1_quality"], color="red", ax=axs[0])
seaborn.scatterplot(tmp.loc[(tmp["men_women"] == 0) & (tmp.T1_seed == 7), "T1_quality"], color="blue", ax=axs[0])
seaborn.scatterplot(tmp.loc[(tmp["men_women"] == 0) & (tmp.T1_seed == 16), "T1_quality"], color="green", ax=axs[0])

seaborn.lineplot(tmp.loc[tmp["men_women"] == 1, "T1_quality"], color="lightgray", ax=axs[1])
seaborn.scatterplot(tmp.loc[(tmp["men_women"] == 1) & (tmp.T1_seed == 1), "T1_quality"], color="red", ax=axs[1])
seaborn.scatterplot(tmp.loc[(tmp["men_women"] == 1) & (tmp.T1_seed == 7), "T1_quality"], color="blue", ax=axs[1])
seaborn.scatterplot(tmp.loc[(tmp["men_women"] == 1) & (tmp.T1_seed == 16), "T1_quality"], color="green", ax=axs[1])
# Out:
# <Axes: ylabel='T1_quality'>

# %%
tmp["QualitySeed"] = (
    (tmp.groupby(["Season", "men_women"])["T1_quality"].rank(ascending=False) // 4 + 1).clip(1, 16).astype(int)
)
pd.pivot_table(data=tmp, index="T1_seed", columns="QualitySeed", values="men_women", aggfunc="count").fillna(0).astype(int).style.bar(color="#5fba7d", vmin=0, vmax=50)
# Out:
# <style type="text/css">
# #T_b1351_row0_col0, #T_b1351_row14_col15, #T_b1351_row15_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_b1351_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 90.0%, transparent 90.0%);
# }
# #T_b1351_row0_col2, #T_b1351_row6_col5, #T_b1351_row6_col10, #T_b1351_row8_col6, #T_b1351_row10_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 24.0%, transparent 24.0%);
# }
# #T_b1351_row0_col3, #T_b1351_row1_col5, #T_b1351_row2_col9, #T_b1351_row4_col9, #T_b1351_row5_col11, #T_b1351_row9_col3, #T_b1351_row9_col12, #T_b1351_row10_col5, #T_b1351_row13_col9, #T_b1351_row13_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 8.0%, transparent 8.0%);
# }
# #T_b1351_row0_col4, #T_b1351_row0_col5, #T_b1351_row0_col6, #T_b1351_row0_col8, #T_b1351_row2_col10, #T_b1351_row3_col10, #T_b1351_row5_col0, #T_b1351_row5_col12, #T_b1351_row8_col13, #T_b1351_row8_col14, #T_b1351_row9_col1, #T_b1351_row9_col13, #T_b1351_row9_col14, #T_b1351_row10_col1, #T_b1351_row10_col2, #T_b1351_row10_col3, #T_b1351_row11_col2, #T_b1351_row11_col4, #T_b1351_row12_col7, #T_b1351_row13_col7, #T_b1351_row13_col8, #T_b1351_row14_col9, #T_b1351_row14_col11, #T_b1351_row15_col8, #T_b1351_row15_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 2.0%, transparent 2.0%);
# }
# #T_b1351_row0_col7, #T_b1351_row0_col9, #T_b1351_row0_col10, #T_b1351_row0_col11, #T_b1351_row0_col12, #T_b1351_row0_col13, #T_b1351_row0_col14, #T_b1351_row0_col15, #T_b1351_row1_col7, #T_b1351_row1_col8, #T_b1351_row1_col9, #T_b1351_row1_col10, #T_b1351_row1_col11, #T_b1351_row1_col12, #T_b1351_row1_col13, #T_b1351_row1_col14, #T_b1351_row1_col15, #T_b1351_row2_col8, #T_b1351_row2_col11, #T_b1351_row2_col12, #T_b1351_row2_col13, #T_b1351_row2_col14, #T_b1351_row2_col15, #T_b1351_row3_col11, #T_b1351_row3_col12, #T_b1351_row3_col13, #T_b1351_row3_col14, #T_b1351_row3_col15, #T_b1351_row4_col0, #T_b1351_row4_col12, #T_b1351_row4_col13, #T_b1351_row4_col14, #T_b1351_row4_col15, #T_b1351_row5_col13, #T_b1351_row5_col14, #T_b1351_row5_col15, #T_b1351_row6_col0, #T_b1351_row6_col13, #T_b1351_row6_col14, #T_b1351_row6_col15, #T_b1351_row7_col0, #T_b1351_row7_col1, #T_b1351_row7_col13, #T_b1351_row7_col14, #T_b1351_row7_col15, #T_b1351_row8_col0, #T_b1351_row8_col2, #T_b1351_row8_col15, #T_b1351_row9_col0, #T_b1351_row9_col15, #T_b1351_row10_col0, #T_b1351_row10_col15, #T_b1351_row11_col0, #T_b1351_row11_col1, #T_b1351_row11_col3, #T_b1351_row12_col0, #T_b1351_row12_col1, #T_b1351_row12_col2, #T_b1351_row12_col3, #T_b1351_row12_col4, #T_b1351_row12_col5, #T_b1351_row12_col6, #T_b1351_row13_col0, #T_b1351_row13_col1, #T_b1351_row13_col2, #T_b1351_row13_col3, #T_b1351_row13_col4, #T_b1351_row13_col5, #T_b1351_row13_col6, #T_b1351_row14_col0, #T_b1351_row14_col1, #T_b1351_row14_col2, #T_b1351_row14_col3, #T_b1351_row14_col4, #T_b1351_row14_col5, #T_b1351_row14_col6, #T_b1351_row14_col7, #T_b1351_row14_col8, #T_b1351_row15_col0, #T_b1351_row15_col1, #T_b1351_row15_col2, #T_b1351_row15_col3, #T_b1351_row15_col4, #T_b1351_row15_col5, #T_b1351_row15_col6, #T_b1351_row15_col7, #T_b1351_row15_col9, #T_b1351_row15_col11 {
#   width: 10em;
# }
# #T_b1351_row1_col0, #T_b1351_row3_col4, #T_b1351_row6_col4, #T_b1351_row9_col9, #T_b1351_row12_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 36.0%, transparent 36.0%);
# }
# #T_b1351_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.0%, transparent 98.0%);
# }
# #T_b1351_row1_col2, #T_b1351_row14_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 84.0%, transparent 84.0%);
# }
# #T_b1351_row1_col3, #T_b1351_row4_col4, #T_b1351_row7_col7, #T_b1351_row10_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 40.0%, transparent 40.0%);
# }
# #T_b1351_row1_col4, #T_b1351_row2_col6, #T_b1351_row3_col0, #T_b1351_row8_col12, #T_b1351_row10_col4, #T_b1351_row13_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 10.0%, transparent 10.0%);
# }
# #T_b1351_row1_col6, #T_b1351_row3_col9, #T_b1351_row4_col11, #T_b1351_row6_col1, #T_b1351_row6_col12, #T_b1351_row8_col1, #T_b1351_row9_col2, #T_b1351_row10_col14, #T_b1351_row11_col5, #T_b1351_row11_col6, #T_b1351_row11_col15, #T_b1351_row12_col8, #T_b1351_row14_col10, #T_b1351_row15_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 4.0%, transparent 4.0%);
# }
# #T_b1351_row2_col0, #T_b1351_row4_col1, #T_b1351_row5_col10, #T_b1351_row6_col3, #T_b1351_row7_col3, #T_b1351_row7_col4, #T_b1351_row7_col11, #T_b1351_row8_col3, #T_b1351_row10_col13, #T_b1351_row11_col7, #T_b1351_row12_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 12.0%, transparent 12.0%);
# }
# #T_b1351_row2_col1, #T_b1351_row2_col5, #T_b1351_row9_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 32.0%, transparent 32.0%);
# }
# #T_b1351_row2_col2, #T_b1351_row11_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 66.0%, transparent 66.0%);
# }
# #T_b1351_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 60.0%, transparent 60.0%);
# }
# #T_b1351_row2_col4, #T_b1351_row12_col14, #T_b1351_row13_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 52.0%, transparent 52.0%);
# }
# #T_b1351_row2_col7, #T_b1351_row3_col8, #T_b1351_row5_col1, #T_b1351_row6_col2, #T_b1351_row7_col2, #T_b1351_row12_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 6.0%, transparent 6.0%);
# }
# #T_b1351_row3_col1, #T_b1351_row7_col10, #T_b1351_row10_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 30.0%, transparent 30.0%);
# }
# #T_b1351_row3_col2, #T_b1351_row4_col6, #T_b1351_row6_col7, #T_b1351_row6_col8, #T_b1351_row7_col9, #T_b1351_row9_col10, #T_b1351_row14_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 44.0%, transparent 44.0%);
# }
# #T_b1351_row3_col3, #T_b1351_row4_col3, #T_b1351_row8_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 50.0%, transparent 50.0%);
# }
# #T_b1351_row3_col5, #T_b1351_row11_col13, #T_b1351_row15_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 42.0%, transparent 42.0%);
# }
# #T_b1351_row3_col6, #T_b1351_row4_col5, #T_b1351_row5_col7, #T_b1351_row6_col6, #T_b1351_row7_col6, #T_b1351_row7_col8, #T_b1351_row8_col10, #T_b1351_row13_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 38.0%, transparent 38.0%);
# }
# #T_b1351_row3_col7, #T_b1351_row10_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 18.0%, transparent 18.0%);
# }
# #T_b1351_row4_col2, #T_b1351_row4_col7, #T_b1351_row5_col6, #T_b1351_row6_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 28.0%, transparent 28.0%);
# }
# #T_b1351_row4_col8, #T_b1351_row4_col10, #T_b1351_row5_col2, #T_b1351_row7_col12, #T_b1351_row8_col5, #T_b1351_row9_col4, #T_b1351_row11_col14, #T_b1351_row14_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 14.0%, transparent 14.0%);
# }
# #T_b1351_row5_col3, #T_b1351_row9_col7, #T_b1351_row11_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 26.0%, transparent 26.0%);
# }
# #T_b1351_row5_col4, #T_b1351_row10_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 46.0%, transparent 46.0%);
# }
# #T_b1351_row5_col5, #T_b1351_row10_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 58.0%, transparent 58.0%);
# }
# #T_b1351_row5_col8, #T_b1351_row5_col9, #T_b1351_row8_col4, #T_b1351_row11_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 20.0%, transparent 20.0%);
# }
# #T_b1351_row6_col11, #T_b1351_row9_col5, #T_b1351_row12_col10, #T_b1351_row15_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 16.0%, transparent 16.0%);
# }
# #T_b1351_row7_col5, #T_b1351_row8_col7, #T_b1351_row9_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 34.0%, transparent 34.0%);
# }
# #T_b1351_row8_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5f

# %%
from sklearn.metrics import roc_auc_score

print("Seed AUC    :", np.round(roc_auc_score(1 - tourney_data["win"], tourney_data["T1_seed"] - tourney_data["T2_seed"]), 3))
print("Quality AUC :", np.round(roc_auc_score(tourney_data["win"], tourney_data["T1_quality"] - tourney_data["T2_quality"]), 3))
# Out:
# Seed AUC    : 0.807
# Quality AUC : 0.825

# %%
# who is better, experts or statistics, by season
for s in sorted(set(tourney_data['Season'])):
    st = tourney_data['Season'] == s
    print(s, 
          a:=np.round(roc_auc_score(1-tourney_data.loc[st, "win"],tourney_data.loc[st, 'T1_seed'] - tourney_data.loc[st, 'T2_seed']),3),
          b:=np.round(roc_auc_score(tourney_data.loc[st, "win"],tourney_data.loc[st, 'T1_quality'] - tourney_data.loc[st, 'T2_quality']),3),
          np.where(a>b, '', 'Q')
         )
# Out:
# 2003 0.807 0.779
# 2004 0.823 0.81
# 2005 0.792 0.811 Q
# 2006 0.75 0.781 Q
# 2007 0.902 0.838
# 2008 0.817 0.851 Q
# 2009 0.84 0.843 Q
# 2010 0.804 0.808 Q
# 2011 0.789 0.816 Q
# 2012 0.828 0.855 Q
# 2013 0.792 0.819 Q
# 2014 0.779 0.816 Q
# 2015 0.85 0.87 Q
# 2016 0.787 0.825 Q
# 2017 0.842 0.851 Q
# 2018 0.786 0.794 Q
# 2019 0.85 0.88 Q
# 2021 0.78 0.818 Q
# 2022 0.77 0.794 Q
# 2023 0.781 0.793 Q
# 2024 0.839 0.839 Q

# %% [markdown]
# ## <<- Machine Learning model ->>

# %%
features = [
    ### EASY FEATURES ###
    "men_women",    
    "T1_seed",
    "T2_seed",
    "Seed_diff",
    ### MEDIUM FEATURES ###
    "T1_avg_Score",
    #"T1_avg_FGM",
    "T1_avg_FGA",
    #"T1_avg_FGM3",
    #"T1_avg_FGA3",
    #"T1_avg_FTM",
    #"T1_avg_FTA",
    #"T1_avg_OR",
    #"T1_avg_DR",
    #"T1_avg_Ast",
    #"T1_avg_TO",
    #"T1_avg_Stl",
    "T1_avg_Blk",
    "T1_avg_PF",
    #"T1_avg_opponent_Score",
    #"T1_avg_opponent_FGM",
    "T1_avg_opponent_FGA",
    #"T1_avg_opponent_FGM3",
    #"T1_avg_opponent_FGA3",
    #"T1_avg_opponent_FTM",
    #"T1_avg_opponent_FTA",
    #"T1_avg_opponent_OR",
    #"T1_avg_opponent_DR",
    #"T1_avg_opponent_Ast",
    #"T1_avg_opponent_TO",
    #"T1_avg_opponent_Stl",
    "T1_avg_opponent_Blk",
    "T1_avg_opponent_PF",
    "T1_avg_PointDiff",
    "T2_avg_Score",
    #"T2_avg_FGM",
    "T2_avg_FGA",
    #"T2_avg_FGM3",
    #"T2_avg_FGA3",
    #"T2_avg_FTM",
    #"T2_avg_FTA",
    #"T2_avg_OR",
    #"T2_avg_DR",
    #"T2_avg_Ast",
    #"T2_avg_TO",
    #"T2_avg_Stl",
    "T2_avg_Blk",
    "T2_avg_PF",
    #"T2_avg_opponent_Score",
    #"T2_avg_opponent_FGM",
    "T2_avg_opponent_FGA",
    #"T2_avg_opponent_FGM3",
    #"T2_avg_opponent_FGA3",
    #"T2_avg_opponent_FTM",
    #"T2_avg_opponent_FTA",
    #"T2_avg_opponent_OR",
    #"T2_avg_opponent_DR",
    #"T2_avg_opponent_Ast",
    #"T2_avg_opponent_TO",
    #"T2_avg_opponent_Stl",
    "T2_avg_opponent_Blk",
    "T2_avg_opponent_PF",
    "T2_avg_PointDiff",
    ### HARD FEATURES ###
    "T1_elo",
    "T2_elo",    
    "elo_diff",
    ### HARDEST FEATURES ###
    "T1_quality",
    "T2_quality",
]

print(f"Number of features {len(features)}")
# Out:
# Number of features 25

# %%
import xgboost as xgb

param = {}
param["objective"] = "reg:squarederror"
param["booster"] = "gbtree"
param["eta"] = 0.01
param["subsample"] = 0.6
param["colsample_bynode"] = 0.8
param["num_parallel_tree"] = 2
param["min_child_weight"] = 4
param["max_depth"] = 4
param["tree_method"] = "hist"
param['grow_policy'] = 'lossguide'
param["max_bin"] = 32

num_rounds = 700

# %% [markdown]
# ![crossvalidation](https://miro.medium.com/v2/resize:fit:940/1*lOZqYqwmuW1lg6fitwqXxA.png)

# %%
from sklearn.metrics import mean_absolute_error, brier_score_loss

models = {}
oof_mae = []
oof_preds = []
oof_targets = []
oof_ss = []

# leave-one-season out models
for oof_season in set(tourney_data.Season):
    x_train = tourney_data.loc[tourney_data["Season"] != oof_season, features].values
    y_train = tourney_data.loc[tourney_data["Season"] != oof_season, "PointDiff"].values
    x_val = tourney_data.loc[tourney_data["Season"] == oof_season, features].values
    y_val = tourney_data.loc[tourney_data["Season"] == oof_season, "PointDiff"].values
    s_val = tourney_data.loc[tourney_data["Season"] == oof_season, "Season"].values
    
    dtrain = xgb.DMatrix(x_train, label=y_train)
    dval = xgb.DMatrix(x_val, label=y_val)
    models[oof_season] = xgb.train(
        params=param,
        dtrain=dtrain,
        num_boost_round = num_rounds,        
    )
    preds = models[oof_season].predict(dval)
    print(f"oof season {oof_season} mae: {mean_absolute_error(y_val, preds)}")
    oof_mae.append(mean_absolute_error(y_val, preds))
    oof_preds += list(preds)
    oof_targets += list(y_val)
    oof_ss += list(s_val)
    
print(f"average mae: {np.mean(oof_mae)}")
# Out:
# oof season 2003 mae: 8.779082318323587
# oof season 2004 mae: 7.834599122485249
# oof season 2005 mae: 7.845755078353816
# oof season 2006 mae: 8.718847807256841
# oof season 2007 mae: 7.6201841528837875
# oof season 2008 mae: 9.852967907907441
# oof season 2009 mae: 9.320242723627274
# oof season 2010 mae: 8.813641456309918
# oof season 2011 mae: 9.901676826078413
# oof season 2012 mae: 8.302524356341435
# oof season 2013 mae: 9.918197525913676
# oof season 2014 mae: 10.146390771136755
# oof season 2015 mae: 7.857889609860305
# oof season 2016 mae: 10.170979653698767
# oof season 2017 mae: 9.9991237170257
# oof season 2018 mae: 10.364734003102232
# oof season 2019 mae: 8.859820423891337
# oof season 2021 mae: 10.557468777493566
# oof season 2022 mae: 10.63396873441714
# oof season 2023 mae: 9.63203377538526
# oof season 2024 mae: 9.455410432570906
# average mae: 9.26597805590778

# %%
df = pd.DataFrame(
    {"Season": oof_ss, "pred": oof_preds, "label": [(t > 0) * 1 for t in oof_targets], "men_women": tourney_data["men_women"]}
)
df["pred_pointdiff"] = df["pred"].astype(int)

xdf_all = df.clip(-30, 30).groupby("pred_pointdiff")["label"].mean().reset_index(name="average_win_pct")
xdf_men = df.clip(-30, 30).loc[df["men_women"] == 0].groupby("pred_pointdiff")["label"].mean().reset_index(name="average_win_pct")
xdf_women = df.clip(-30, 30).loc[df["men_women"] == 1].groupby("pred_pointdiff")["label"].mean().reset_index(name="average_win_pct")

seaborn.lineplot(x=xdf_all["pred_pointdiff"], y=xdf_all["average_win_pct"])
seaborn.lineplot(x=xdf_men["pred_pointdiff"], y=xdf_men["average_win_pct"])
seaborn.lineplot(x=xdf_women["pred_pointdiff"], y=xdf_women["average_win_pct"])
# Out:
# <Axes: xlabel='pred_pointdiff', ylabel='average_win_pct'>

# %%
from scipy.interpolate import UnivariateSpline

t = 25
dat = list(zip(oof_preds, np.array(oof_targets)>0))
dat = sorted(dat, key = lambda x: x[0])
pred, label = list(zip(*dat))
spline_model = UnivariateSpline(np.clip(pred, -t, t), label, k=5)
spline_fit = np.clip(spline_model(np.clip(oof_preds, -t, t)), 0.01, 0.99)
print(f"brier: {brier_score_loss(np.array(oof_targets)>0, spline_fit)}")
df["spline"] = spline_fit
xdf = df.clip(-30,30).groupby('pred_pointdiff')[['spline','label']].mean().reset_index()

plt.figure()
plt.plot(xdf['pred_pointdiff'],xdf['label'])
plt.plot(xdf['pred_pointdiff'],xdf['spline'])
# Out:
# brier: 0.1682794856743049

# %%
print(f"brier: {brier_score_loss(np.array(oof_targets)>0, spline_fit)}")

for oof_season in set(tourney_data.Season):
    x = df.loc[df["Season"] == oof_season, "spline"].values
    y = df.loc[df["Season"] == oof_season, "label"].values
    print(oof_season, np.round(brier_score_loss(y, x),5))
# Out:
# brier: 0.1682794856743049
# 2003 0.1811
# 2004 0.16835
# 2005 0.17013
# 2006 0.19181
# 2007 0.14216
# 2008 0.15428
# 2009 0.16902
# 2010 0.16723
# 2011 0.1834
# 2012 0.152
# 2013 0.17244
# 2014 0.1769
# 2015 0.14444
# 2016 0.17177
# 2017 0.16007
# 2018 0.17855
# 2019 0.13989
# 2021 0.17773
# 2022 0.18851
# 2023 0.18733
# 2024 0.15544

# %% [markdown]
# ## <<- Make submission ->>

# %%
##################################################################################
#### Stage2 data should be available on March 17, check forums for updates #######
##################################################################################

X = pd.read_csv(f"{data_dir}/SampleSubmissionStage2.csv")
X
# Out:
#                     ID  Pred
# 0       2025_1101_1102   0.5
# 1       2025_1101_1103   0.5
# 2       2025_1101_1104   0.5
# 3       2025_1101_1105   0.5
# 4       2025_1101_1106   0.5
# ...                ...   ...
# 131402  2025_3477_3479   0.5
# 131403  2025_3477_3480   0.5
# 131404  2025_3478_3479   0.5
# 131405  2025_3478_3480   0.5
# 131406  2025_3479_3480   0.5
#
# [131407 rows x 2 columns]

# %%
# construct dataframe for submission
X['Season'] = X['ID'].apply(lambda t: int(t.split('_')[0]))
X['T1_TeamID'] = X['ID'].apply(lambda t: int(t.split('_')[1]))
X['T2_TeamID'] = X['ID'].apply(lambda t: int(t.split('_')[2]))
X['men_women'] = X['T1_TeamID'].apply(lambda t: 0 if str(t)[0]=='1' else 1)
X = pd.merge(X, ss_T1, on = ['Season', 'T1_TeamID'], how = 'left')
X = pd.merge(X, ss_T2, on = ['Season', 'T2_TeamID'], how = 'left')
X = pd.merge(X, seeds_T1, on = ['Season', 'T1_TeamID'], how = 'left')
X = pd.merge(X, seeds_T2, on = ['Season', 'T2_TeamID'], how = 'left')
X = pd.merge(X, glm_quality_T1, on=["Season", "T1_TeamID"], how="left")
X = pd.merge(X, glm_quality_T2, on=["Season", "T2_TeamID"], how="left")
X = pd.merge(X, elos_T1, on=["Season", "T1_TeamID"], how="left")
X = pd.merge(X, elos_T2, on=["Season", "T2_TeamID"], how="left")
X["Seed_diff"] = X["T2_seed"] - X["T1_seed"]
X["elo_diff"] = X["T1_elo"] - X["T2_elo"]
X["diff_quality"] = X["T1_quality"] - X["T2_quality"]

# %%
# run models on given dataset
preds = []
for oof_season in set(tourney_data.Season):
    dtest = xgb.DMatrix(X[features].values)
    margin_preds = models[oof_season].predict(dtest) * 1.0 # aggressive submissions >1, conservative submissions <1
    probs = np.clip(spline_model(np.clip(margin_preds, -t, t)), 0.01, 0.99)
    preds.append(probs)
X['Pred'] = np.array(preds).mean(axis=0)

# %%
# sanity check to check for seed matchup win probability distribution 
pd.pivot_table(data = X, index='T1_seed', columns='T2_seed', values='Pred', aggfunc='mean').style.bar(color='#5fba7d', vmin=0, vmax=1)
# Out:
# <style type="text/css">
# #T_28f60_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 49.6%, transparent 49.6%);
# }
# #T_28f60_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 68.2%, transparent 68.2%);
# }
# #T_28f60_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 74.4%, transparent 74.4%);
# }
# #T_28f60_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 80.0%, transparent 80.0%);
# }
# #T_28f60_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 83.9%, transparent 83.9%);
# }
# #T_28f60_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 82.9%, transparent 82.9%);
# }
# #T_28f60_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 85.1%, transparent 85.1%);
# }
# #T_28f60_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 87.6%, transparent 87.6%);
# }
# #T_28f60_row0_col8, #T_28f60_row4_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 88.5%, transparent 88.5%);
# }
# #T_28f60_row0_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 90.9%, transparent 90.9%);
# }
# #T_28f60_row0_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 91.2%, transparent 91.2%);
# }
# #T_28f60_row0_col11, #T_28f60_row1_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 95.1%, transparent 95.1%);
# }
# #T_28f60_row0_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 97.7%, transparent 97.7%);
# }
# #T_28f60_row0_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.8%, transparent 98.8%);
# }
# #T_28f60_row0_col14, #T_28f60_row0_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 99.0%, transparent 99.0%);
# }
# #T_28f60_row1_col0, #T_28f60_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 34.2%, transparent 34.2%);
# }
# #T_28f60_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 55.1%, transparent 55.1%);
# }
# #T_28f60_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 64.8%, transparent 64.8%);
# }
# #T_28f60_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 71.4%, transparent 71.4%);
# }
# #T_28f60_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 77.6%, transparent 77.6%);
# }
# #T_28f60_row1_col5, #T_28f60_row12_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 76.2%, transparent 76.2%);
# }
# #T_28f60_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 76.6%, transparent 76.6%);
# }
# #T_28f60_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 80.1%, transparent 80.1%);
# }
# #T_28f60_row1_col8, #T_28f60_row3_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 87.0%, transparent 87.0%);
# }
# #T_28f60_row1_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 83.2%, transparent 83.2%);
# }
# #T_28f60_row1_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 84.8%, transparent 84.8%);
# }
# #T_28f60_row1_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 87.1%, transparent 87.1%);
# }
# #T_28f60_row1_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 96.1%, transparent 96.1%);
# }
# #T_28f60_row1_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 97.2%, transparent 97.2%);
# }
# #T_28f60_row1_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.7%, transparent 98.7%);
# }
# #T_28f60_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 17.8%, transparent 17.8%);
# }
# #T_28f60_row2_col1, #T_28f60_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 36.7%, transparent 36.7%);
# }
# #T_28f60_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 52.0%, transparent 52.0%);
# }
# #T_28f60_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 60.0%, transparent 60.0%);
# }
# #T_28f60_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 66.0%, transparent 66.0%);
# }
# #T_28f60_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 64.0%, transparent 64.0%);
# }
# #T_28f60_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 68.9%, transparent 68.9%);
# }
# #T_28f60_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 74.1%, transparent 74.1%);
# }
# #T_28f60_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 75.0%, transparent 75.0%);
# }
# #T_28f60_row2_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 79.1%, transparent 79.1%);
# }
# #T_28f60_row2_col10, #T_28f60_row9_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 78.7%, transparent 78.7%);
# }
# #T_28f60_row2_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 84.1%, transparent 84.1%);
# }
# #T_28f60_row2_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 87.2%, transparent 87.2%);
# }
# #T_28f60_row2_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 95.7%, transparent 95.7%);
# }
# #T_28f60_row2_col14, #T_28f60_row3_col14 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 94.9%, transparent 94.9%);
# }
# #T_28f60_row2_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 98.3%, transparent 98.3%);
# }
# #T_28f60_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 13.7%, transparent 13.7%);
# }
# #T_28f60_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 32.2%, transparent 32.2%);
# }
# #T_28f60_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 41.8%, transparent 41.8%);
# }
# #T_28f60_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 54.2%, transparent 54.2%);
# }
# #T_28f60_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 60.6%, transparent 60.6%);
# }
# #T_28f60_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 60.1%, transparent 60.1%);
# }
# #T_28f60_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 64.2%, transparent 64.2%);
# }
# #T_28f60_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 70.7%, transparent 70.7%);
# }
# #T_28f60_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 72.1%, transparent 72.1%);
# }
# #T_28f60_row3_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 71.5%, transparent 71.5%);
# }
# #T_28f60_row3_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 76.0%, transparent 76.0%);
# }
# #T_28f60_row3_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 79.7%, transparent 79.7%);
# }
# #T_28f60_row3_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 91.7%, transparent 91.7%);
# }
# #T_28f60_row3_col15 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 97.9%, transparent 97.9%);
# }
# #T_28f60_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 11.7%, transparent 11.7%);
# }
# #T_28f60_row4_col1, #T_28f60_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 28.2%, transparent 28.2%);
# }
# #T_28f60_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 45.3%, transparent 45.3%);
# }
# #T_28f60_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 50.8%, transparent 50.8%);
# }
# #T_28f60_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 53.2%, transparent 53.2%);
# }
# #T_28f60_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 58.6%, transparent 58.6%);
# }
# #T_28f60_row4_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 65.5%, transparent 65.5%);
# }
# #T_28f60_row4_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 67.1%, transparent 67.1%);
# }
# #T_28f60_row4_col9 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 67.2%, transparent 67.2%);
# }
# #T_28f60_row4_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 66.9%, transparent 66.9%);
# }
# #T_28f60_row4_col11 {
#   width: 10em;
#   backgrou

# %%
X[['ID','Pred']].to_csv('./predictions/raddar_predictions.csv',index=None)
